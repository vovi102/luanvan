# %% [markdown]
# # T3.1 GoogleSQL Template Validation
#
# Inspect contract-v2 `templates.json` and invoke the shared BigQuery validation CLI.

# %%
import json
from pathlib import Path

templates_path = Path("../src/nl2sparql/dataset/templates/templates.json")
templates = json.loads(templates_path.read_text(encoding="utf-8"))
len(templates), templates[0]["id"], templates[0]["sql_template"][:80]

# %%
# Run from the repository root; remove --live for offline-only checks.
command = "uv run python scripts/08_validate_sql_templates.py --live"
command
