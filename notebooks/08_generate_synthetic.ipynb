# %% [markdown]
# # T3.2 Synthetic Stage A Generation
#
# Offline scaffold for rendering template records before live Fuseki verification.

# %%
from pathlib import Path
from nl2sparql.dataset.generate import load_templates, generate_stage_a_records, write_jsonl, write_stats

templates = load_templates(Path("../src/nl2sparql/dataset/templates/templates.json"))
records = generate_stage_a_records(templates, target_count=100, seed=42)
len(records), records[0]["template_id"]

# %%
output = Path("../data/dataset/raw/synthetic-stage-a.jsonl")
stats = Path("../data/dataset/raw/stats.md")
# write_jsonl(records, output)
# write_stats(records, stats)
output, stats

# %% [markdown]
# Live Fuseki execution/non-empty filtering remains pending until the full KG is loaded.
