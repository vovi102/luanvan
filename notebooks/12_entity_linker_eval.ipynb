# %% [markdown]
# # Entity-linker evaluation
#
# This notebook delegates all production work to the versioned workflow.

# %%
from scripts.entity_linker_workflow import main

main(
    [
        "evaluate",
        "--ground-truth",
        "data/eval/entity_link_groundtruth.jsonl",
        "--cache-dir",
        "src/nl2sparql/linking/cache",
        "--report",
        "reports/entity_linker_evaluation.json",
        "--local-files-only",
    ]
)
